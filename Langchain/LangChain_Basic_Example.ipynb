# %% [markdown]
# # Lang Chain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Installation

# %%
# !pip install langchain
# !pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain in c:\users\91956\anaconda3\lib\site-packages (0.0.352)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.2 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (0.0.6)
# Requirement already satisfied: langchain-core<0.2,>=0.1 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (0.1.3)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.70 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (0.0.75)
# Requirement already satisfied: numpy<2,>=1 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (1.24.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\91956\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\91956\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\91956\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\91956\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\91956\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\91956\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\91956\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\91956\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\91956\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\91956\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91956\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\91956\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1->langchain) (3.5.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\91956\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\91956\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91956\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91956\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91956\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\91956\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\91956\anaconda3\lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1->langchain) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\91956\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# DEPRECATION: Loading egg at c:\users\91956\anaconda3\lib\site-packages\gscraper-0.0.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %% [markdown]
# # Exercise 1 - Using Lang Chain with Gemini

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI


def configure_access():
    load_dotenv()  # Load environment variables from .env file
    google_credentials = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
    api_key = os.getenv('GOOGLE_API_KEY')
    if not api_key:
        raise ValueError("API key not found in environment variables")

    return api_key

api_key=configure_access()
llm = ChatGoogleGenerativeAI(model="gemini-1.0-pro-latest", google_api_key=api_key)
resp=llm.invoke("What is your name?")
print(resp.content)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from langchain_google_genai import ChatGoogleGenerativeAI
#       6 def configure_access():
#       7     load_dotenv()  # Load environment variables from .env file
#
# File ~\anaconda3\Lib\site-packages\langchain_google_genai\__init__.py:59
#       1 """**LangChain Google Generative AI Integration**
#       2
#       3 This module integrates Google's Generative AI models, specifically the Gemini series, with the LangChain framework. It provides classes for interacting with chat models and generating embeddings, leveraging Google's advanced AI capabilities.
#    (...)
#      55 ```
#      56 """  # noqa: E501
#      58 from langchain_google_genai._enums import HarmBlockThreshold, HarmCategory
# ---> 59 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      60 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      61 from langchain_google_genai.genai_aqa import (
#      62     AqaInput,
#      63     AqaOutput,
#      64     GenAIAqa,
#      65 )
#
# File ~\anaconda3\Lib\site-packages\langchain_google_genai\chat_models.py:55
#      52 from langchain_core.language_models import LanguageModelInput
#      53 from langchain_core.language_models.chat_models import BaseChatModel
#      54 from langchain_core.messages import (
# ---> 55     AIMessage,
#      56     AIMessageChunk,
#      57     BaseMessage,
#      58     FunctionMessage,
#      59     HumanMessage,
#      60     InvalidToolCall,
#      61     SystemMessage,
#      62     ToolCall,
#      63     ToolCallChunk,
#      64     ToolMessage,
#      65 )
#      66 from langchain_core.output_parsers.openai_tools import parse_tool_calls
#      67 from langchain_core.outputs import ChatGeneration, ChatGenerationChunk, ChatResult
#
# ImportError: cannot import name 'InvalidToolCall' from 'langchain_core.messages' (C:\Users\91956\anaconda3\Lib\site-packages\langchain_core\messages\__init__.py)

# %% [markdown]
# # Exercise 2 - Using Lang Chain with Gemini - System and User Prompt

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain


def configure_access():
    load_dotenv()  # Load environment variables from .env file
    google_credentials = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
    api_key = os.getenv('GOOGLE_API_KEY')
    if not api_key:
        raise ValueError("API key not found in environment variables")

    return api_key

api_key=configure_access()
llm = ChatGoogleGenerativeAI(model="gemini-1.0-pro-latest", google_api_key=api_key)

tweet_prompt = PromptTemplate.from_template("You are a content creator. Write me a tweet about {topic}.")

tweet_chain = LLMChain(llm=llm, prompt=tweet_prompt, verbose=True)

if __name__=="__main__":
    topic = "how ai is really cool"
    resp = tweet_chain.run(topic=topic)
    print(resp)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from langchain_google_genai import ChatGoogleGenerativeAI
#       4 from langchain.prompts import PromptTemplate
#       5 from langchain.chains import LLMChain
#
# File ~\anaconda3\Lib\site-packages\langchain_google_genai\__init__.py:59
#       1 """**LangChain Google Generative AI Integration**
#       2
#       3 This module integrates Google's Generative AI models, specifically the Gemini series, with the LangChain framework. It provides classes for interacting with chat models and generating embeddings, leveraging Google's advanced AI capabilities.
#    (...)
#      55 ```
#      56 """  # noqa: E501
#      58 from langchain_google_genai._enums import HarmBlockThreshold, HarmCategory
# ---> 59 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      60 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      61 from langchain_google_genai.genai_aqa import (
#      62     AqaInput,
#      63     AqaOutput,
#      64     GenAIAqa,
#      65 )
#
# File ~\anaconda3\Lib\site-packages\langchain_google_genai\chat_models.py:55
#      52 from langchain_core.language_models import LanguageModelInput
#      53 from langchain_core.language_models.chat_models import BaseChatModel
#      54 from langchain_core.messages import (
# ---> 55     AIMessage,
#      56     AIMessageChunk,
#      57     BaseMessage,
#      58     FunctionMessage,
#      59     HumanMessage,
#      60     InvalidToolCall,
#      61     SystemMessage,
#      62     ToolCall,
#      63     ToolCallChunk,
#      64     ToolMessage,
#      65 )
#      66 from langchain_core.output_parsers.openai_tools import parse_tool_calls
#      67 from langchain_core.outputs import ChatGeneration, ChatGenerationChunk, ChatResult
#
# ImportError: cannot import name 'InvalidToolCall' from 'langchain_core.messages' (C:\Users\91956\anaconda3\Lib\site-packages\langchain_core\messages\__init__.py)
